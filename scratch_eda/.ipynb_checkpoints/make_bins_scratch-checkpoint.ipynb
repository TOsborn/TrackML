# %%
import sys
from importlib import reload

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

trackml_path = '/home/ec2-user/SageMaker/TrackML'
if trackml_path not in sys.path:
    sys.path.append(trackml_path)
    
from detector_grid import detector_grid
reload(detector_grid)

from helper_functions.file_utilities import file_url

hits = hit_binning.prep_hits(list(range(21000, 21011)))
grid_boundaries = hit_binning.make_bins(
    hits, 100, 100, 100, add_cols=True)

hits.head()
# Out:
#    hit_id  event_id          R     theta        x         y       z  \
# 0       1     21000  88.037293 -1.738907 -86.7962 -14.73040 -1502.5
# 1       2     21000  69.562627 -1.728124 -68.7035 -10.89900 -1502.5
# 2       3     21000  56.937925 -1.738587 -56.1383  -9.50887 -1502.5
# 3       4     21000  60.516021 -1.653054 -60.3114  -4.97231 -1502.5
# 4       5     21000  89.839392 -1.669095 -89.4057  -8.81687 -1502.5
#
#   detector_type  volume_id  layer_id  module_id             R_bin  \
# 0          disk          7         2          1  (87.784, 94.633]
# 1          disk          7         2          1  (67.866, 71.107]
# 2          disk          7         2          1  (54.496, 57.433]
# 3          disk          7         2          1  (57.433, 60.581]
# 4          disk          7         2          1  (87.784, 94.633]
#
#           theta_bin               z_bin
# 0  (-1.767, -1.702]  (-1797.5, -1502.5]
# 1  (-1.767, -1.702]  (-1797.5, -1502.5]
# ...

# %%
grid_boundaries.head()
# Out:
#            R     theta       z
# 0  30.055512 -3.141593 -2955.5
# 1  31.464728 -3.081229 -2945.5
# 2  31.613370 -3.018537 -2548.5
# 3  31.937015 -2.955412 -2152.5
# 4  32.018676 -2.891425 -2144.5

# %%
grid_boundaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 3 columns):
# R        101 non-null float64
# theta    101 non-null float64
# z        101 non-null float64
# dtypes: float64(3)
# memory usage: 2.4 KB

# %%
hit_binning.write_boundaries_csv(list(range(21000, 21011)), 100, 100, 100)
grid_boundaries = pd.read_csv('/home/ec2-user/SageMaker/efs/detector_bin_arrays/grid_boundaries.csv')
grid_boundaries
# Out:
#                R     theta           z
# 0      30.055512 -3.141593 -2955.50000
# 1      31.464732 -3.081392 -2945.50000
# 2      31.613370 -3.018882 -2548.50000
# 3      31.937152 -2.955758 -2152.50000
# 4      32.020263 -2.891572 -2144.50000
# 5      32.191180 -2.826609 -1797.50000
# 6      32.564790 -2.768136 -1502.50000
# 7      33.038430 -2.705646 -1498.50000
# 8      33.610389 -2.645892 -1495.50000
# 9      34.478632 -2.581084 -1302.00000
# 10     36.782543 -2.517909 -1224.50000
# 11     39.103594 -2.455736 -1215.50000
# 12     41.377153 -2.390150 -1102.00000
# 13     43.749825 -2.332115 -1097.50000
# 14     46.283799 -2.269060  -989.80000
# 15     48.867603 -2.204647  -962.00000
# 16     51.626060 -2.142314  -958.00000
# 17     54.496446 -2.079120  -896.40513
# 18     57.433306 -2.019763  -822.50000
# 19     60.580835 -1.959571  -818.60000
# 20     64.099841 -1.896782  -817.50000
# 21     67.865647 -1.831441  -748.00000
# 22     71.106708 -1.767142  -702.00000
# ...

# %%
hit_binning.bin_id(663., 2.2, 1000., grid_boundaries)
# Out:
# (86, 86, 86)

# %%
np.linspace(-1., 1., 10, endpoint=False)
# Out:
# array([-1. , -0.8, -0.6, -0.4, -0.2,  0. ,  0.2,  0.4,  0.6,  0.8])

# %%
hits.head()
# Out:
#    hit_id  event_id          R     theta        x         y       z  \
# 0       1     21000  88.037293 -1.738907 -86.7962 -14.73040 -1502.5
# 1       2     21000  69.562627 -1.728124 -68.7035 -10.89900 -1502.5
# 2       3     21000  56.937925 -1.738587 -56.1383  -9.50887 -1502.5
# 3       4     21000  60.516021 -1.653054 -60.3114  -4.97231 -1502.5
# 4       5     21000  89.839392 -1.669095 -89.4057  -8.81687 -1502.5
#
#   detector_type  volume_id  layer_id  module_id             R_bin  \
# 0          disk          7         2          1  (87.784, 94.633]
# 1          disk          7         2          1  (67.866, 71.107]
# 2          disk          7         2          1  (54.496, 57.433]
# 3          disk          7         2          1  (57.433, 60.581]
# 4          disk          7         2          1  (87.784, 94.633]
#
#           theta_bin               z_bin
# 0  (-1.767, -1.702]  (-1797.5, -1502.5]
# 1  (-1.767, -1.702]  (-1797.5, -1502.5]
# ...

# %%
grid_boundaries = hit_binning.make_grid_boundaries(hits, 100)

# %%
np.digitize(np.pi, grid_boundaries.theta)
# Out:
# array(101)

# %%
hits.head()
# Out:
#    hit_id  event_id          R     theta        x         y       z  \
# 0       1     21000  88.037293 -1.738907 -86.7962 -14.73040 -1502.5
# 1       2     21000  69.562627 -1.728124 -68.7035 -10.89900 -1502.5
# 2       3     21000  56.937925 -1.738587 -56.1383  -9.50887 -1502.5
# 3       4     21000  60.516021 -1.653054 -60.3114  -4.97231 -1502.5
# 4       5     21000  89.839392 -1.669095 -89.4057  -8.81687 -1502.5
#
#   detector_type  volume_id  layer_id  module_id             R_bin  \
# 0          disk          7         2          1  (87.784, 94.633]
# 1          disk          7         2          1  (67.866, 71.107]
# 2          disk          7         2          1  (54.496, 57.433]
# 3          disk          7         2          1  (57.433, 60.581]
# 4          disk          7         2          1  (87.784, 94.633]
#
#           theta_bin               z_bin
# 0  (-1.767, -1.702]  (-1797.5, -1502.5]
# 1  (-1.767, -1.702]  (-1797.5, -1502.5]
# ...

# %%
dg = detector_grid.DetectorGrid()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-36b31c710fa8> in <module>()
# ----> 1 dg = detector_grid.DetectorGrid()
#
# NameError: name 'detector_grid' is not defined

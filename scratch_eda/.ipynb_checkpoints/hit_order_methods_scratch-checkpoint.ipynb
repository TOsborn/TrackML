# %%
import os

import numpy as np
import pandas as pd


def file_url(category, event_id=None, train_or_test="train"):
    """Returns the path of a csv corresponding to a given event and data category.
    
    Arguments:
    category -- one of "cells", "hits", "particles", "truth", "blacklist", "detectors",
        "sample_submission" or "hit_orders".
    event_id -- the integer id of an event. Should be included unless category is "detectors" or
        "sample submission". Ensure that event_id and train_or_test are consistent with each other.
    train_or_test -- one of "train" (default) or "test".
    
    TODO: Check for valid input.
    """
    if category.startswith('blacklist'):
        folder = 'dataset/blacklist'
    elif category == 'hit_orders':
        folder = 'particles-in-order'
    elif category in ('sample_submission', 'detectors'):
        return '/home/ec2-user/SageMaker/efs/dataset/{0}.csv'.format(category)
    else:
        folder = 'dataset/' + train_or_test
    return '/home/ec2-user/SageMaker/efs/{0}/event{1:09d}-{2}.csv'.format(folder, event_id, category)

def write_hit_orders_csv(event_id):
    """Writes hit_order csv for an event."""
    generate_hit_orders(event_id).to_csv(file_url('hit_orders', event_id), index=False)

def generate_hit_orders(event_id):
    """Generates hit_order dataframe for an event.
    
    When finished, prints the number of valid particles and hits, as well as the number and
    proportion of particles which were successfully placed in order.
    """
    # load truth, blacklist_particles and blacklist_hits files for event 1000.
    truth = pd.read_csv(file_url('truth', event_id))
    blacklist_particles = pd.read_csv(file_url('blacklist_particles', event_id))
    blacklist_hits = pd.read_csv(file_url('blacklist_hits', event_id))

    # filter out track 0 (garbage track), tracks with three or fewer hits, 
    # and rows with blacklisted hits and particles.
    not_blacklist_particle = ~truth.particle_id.isin(blacklist_particles.particle_id)
    not_blacklist_hit = ~truth.hit_id.isin(blacklist_hits.hit_id)
    del blacklist_particles, blacklist_hits

    particle_num_hits = truth.groupby('particle_id')['particle_id'].transform('count')
    not_short_track = particle_num_hits > 3
    del particle_num_hits

    not_particle_zero = truth.particle_id != 0
    
    truth = truth[not_particle_zero & not_blacklist_particle & not_blacklist_hit & not_short_track]
    del not_particle_zero, not_blacklist_particle, not_blacklist_hit, not_short_track
    
    particle_weight = truth.groupby('particle_id')['weight'].transform('sum')
    truth.loc[:, 'weight_order'] = truth.weight/particle_weight
    del particle_weight
    
    truth = truth[['particle_id', 'hit_id', 'tz', 'tpz', 'weight_order']]
    
    # create z_order_dim. This is tz if the z-dimension of the particle's average trajectory
    # is positive and -tz otherwise.
    z_direction = np.sign(truth.groupby('particle_id').tpz.transform('mean'))
    truth.loc[:, 'z_order_dim'] = z_direction*truth.tz
    truth.drop(['tz', 'tpz'], axis=1, inplace=True)
    del z_direction
    
    # create hit_order column.
    truth.loc[:, 'hit_order'] = truth.groupby('particle_id')['z_order_dim'].rank(
        method='first',
        ascending=True
    ).astype(int)
    truth.drop('z_order_dim', axis=1, inplace=True)

    # sort by particle_id and hit_order.
    truth.sort_values(['particle_id', 'hit_order'], inplace=True)
    
    truth.loc[:, 'track_length'] = truth.groupby('particle_id').hit_id.transform('count')
    true_weight_order = truth.groupby(['track_length', 'hit_order']).weight_order.median()
    truth.drop('track_length', axis=1, inplace=True)
    
    # identify and remove particles whose hit order is incorrect.
    # print('truth.groupby particle', truth.groupby('particle_id').values)
    particles_in_order = truth.groupby('particle_id').apply(correct_order(true_weight_order))
    
    total_num_particles = len(particles_in_order)
    mask = particles_in_order.loc[truth.particle_id].values
    truth = truth[mask]
    num_good_particles = len(truth.particle_id.unique())
    
    truth.reset_index(drop=True, inplace=True)
    truth.drop('weight_order', axis=1, inplace=True)
    
    print('total number of scored particles in event:\t', total_num_particles)
    print('number of successfully sorted particles:\t', num_good_particles)
    print('percentage of partices successfully sorted\t:', 
          100*num_good_particles/total_num_particles)

    return truth

def correct_order(true_weight_order):
    """Helper function for generate_hit_order_csv"""
    return lambda particle: np.all(
        np.isclose(
            particle.weight_order.values, true_weight_order.loc[len(particle)].values,
            atol=1e-06
        )
    )

# %%
import os

for event_id in range(10**3, 10**4):
    if os.path.isfile(file_url('truth', event_id)):
        print('event_id:', event_id)
        write_hit_orders_csv(event_id)
        print(2*'\n')
# Out:
# event_id: 1000
# total number of scored particles in event:	 9272
# number of successfully sorted particles:	 9252
# percentage of partices successfully sorted	: 99.78429680759275
#
#
#
# event_id: 1001
# total number of scored particles in event:	 6782
# number of successfully sorted particles:	 6762
# percentage of partices successfully sorted	: 99.70510173989973
#
#
#
# event_id: 1002
# total number of scored particles in event:	 9652
# number of successfully sorted particles:	 9642
# percentage of partices successfully sorted	: 99.89639452963117
#
#
#
# event_id: 1003
# total number of scored particles in event:	 7801
# number of successfully sorted particles:	 7795
# percentage of partices successfully sorted	: 99.92308678374567
#
#
#
# event_id: 1004
# total number of scored particles in event:	 10758
# number of successfully sorted particles:	 10741
# percentage of partices successfully sorted	: 99.84197806283696
#
#
#
# event_id: 1005
# total number of scored particles in event:	 8241
# number of successfully sorted particles:	 8224
# percentage of partices successfully sorted	: 99.793714355054
#
#
#
# event_id: 1006
# total number of scored particles in event:	 8984
# number of successfully sorted particles:	 8969
# percentage of partices successfully sorted	: 99.83303650934995
#
#
#
# event_id: 1007
# total number of scored particles in event:	 8349
# number of successfully sorted particles:	 8331
# percentage of partices successfully sorted	: 99.78440531800216
#
#
#
# event_id: 1008
# total number of scored particles in event:	 8422
# number of successfully sorted particles:	 8404
# percentage of partices successfully sorted	: 99.78627404417003
#
#
#
# event_id: 1009
# total number of scored particles in event:	 8120
# number of successfully sorted particles:	 8102
# percentage of partices successfully sorted	: 99.77832512315271
#
#
#
# event_id: 1010
# total number of scored particles in event:	 7684
# number of successfully sorted particles:	 7673
# percentage of partices successfully sorted	: 99.85684539302447
#
#
#
# event_id: 1011
# total number of scored particles in event:	 8873
# number of successfully sorted particles:	 8855
# percentage of partices successfully sorted	: 99.79713738307224
#
#
#
# event_id: 1012
# total number of scored particles in event:	 8269
# number of successfully sorted particles:	 8249
# percentage of partices successfully sorted	: 99.75813278510098
#
#
#
# event_id: 1013
# total number of scored particles in event:	 7923
# number of successfully sorted particles:	 7911
# percentage of partices successfully sorted	: 99.8485422188565
#
#
#
# event_id: 1014
# total number of scored particles in event:	 9622
# number of successfully sorted particles:	 9602
# percentage of partices successfully sorted	: 99.79214300561213
#
#
#
# event_id: 1015
# total number of scored particles in event:	 9351
# number of successfully sorted particles:	 9326
# percentage of partices successfully sorted	: 99.73264891455459
#
#
#
# event_id: 1016
# total number of scored particles in event:	 8929
# number of successfully sorted particles:	 8904
# percentage of partices successfully sorted	: 99.72001343935491
#
#
#
# event_id: 1017
# total number of scored particles in event:	 9452
# number of successfully sorted particles:	 9431
# percentage of partices successfully sorted	: 99.77782479898434
#
#
#
# event_id: 1018
# total number of scored particles in event:	 6644
# number of successfully sorted particles:	 6633
# percentage of partices successfully sorted	: 99.83443708609272
#
#
#
# event_id: 1019
# total number of scored particles in event:	 9375
# number of successfully sorted particles:	 9358
# percentage of partices successfully sorted	: 99.81866666666667
#
#
#
# event_id: 1020
# total number of scored particles in event:	 6840
# number of successfully sorted particles:	 6827
# percentage of partices successfully sorted	: 99.80994152046783
#
#
#
# event_id: 1021
# total number of scored particles in event:	 7742
# number of successfully sorted particles:	 7728
# percentage of partices successfully sorted	: 99.81916817359856
#
#
#
# event_id: 1022
# total number of scored particles in event:	 7732
# number of successfully sorted particles:	 7721
# percentage of partices successfully sorted	: 99.85773409208484
#
#
#
# event_id: 1023
# total number of scored particles in event:	 9848
# number of successfully sorted particles:	 9832
# percentage of partices successfully sorted	: 99.83753046303818
#
#
#
# event_id: 1024
# total number of scored particles in event:	 8809
# number of successfully sorted particles:	 8794
# percentage of partices successfully sorted	: 99.82971960494949
#
#
#
# event_id: 1025
# total number of scored particles in event:	 9111
# number of successfully sorted particles:	 9091
# percentage of partices successfully sorted	: 99.78048512786741
#
#
#
# event_id: 1026
# total number of scored particles in event:	 9356
# number of successfully sorted particles:	 9342
# percentage of partices successfully sorted	: 99.85036340316374
#
#
#
# event_id: 1027
# total number of scored particles in event:	 8785
# number of successfully sorted particles:	 8770
# percentage of partices successfully sorted	: 99.82925441092772
#
#
#
# event_id: 1028
# total number of scored particles in event:	 8801
# number of successfully sorted particles:	 8789
# percentage of partices successfully sorted	: 99.86365185774343
#
#
#
# event_id: 1029
# total number of scored particles in event:	 8135
# number of successfully sorted particles:	 8114
# percentage of partices successfully sorted	: 99.7418561770129
#
#
#
# event_id: 1030
# total number of scored particles in event:	 8576
# number of successfully sorted particles:	 8564
# percentage of partices successfully sorted	: 99.86007462686567
#
#
#
# event_id: 1031
# total number of scored particles in event:	 9340
# number of successfully sorted particles:	 9317
# percentage of partices successfully sorted	: 99.75374732334048
#
#
#
# event_id: 1032
# total number of scored particles in event:	 7397
# number of successfully sorted particles:	 7384
# percentage of partices successfully sorted	: 99.82425307557118
#
#
#
# event_id: 1033
# total number of scored particles in event:	 6949
# number of successfully sorted particles:	 6939
# percentage of partices successfully sorted	: 99.85609440207224
#
#
#
# event_id: 1034
# total number of scored particles in event:	 8668
# number of successfully sorted particles:	 8650
# percentage of partices successfully sorted	: 99.79233964005537
#
#
#
# event_id: 1035
# total number of scored particles in event:	 7040
# number of successfully sorted particles:	 7030
# percentage of partices successfully sorted	: 99.85795454545455
#
#
#
# event_id: 1036
# total number of scored particles in event:	 7810
# number of successfully sorted particles:	 7799
# percentage of partices successfully sorted	: 99.85915492957747
#
#
#
# event_id: 1037
# total number of scored particles in event:	 8784
# number of successfully sorted particles:	 8766
# percentage of partices successfully sorted	: 99.79508196721312
#
#
#
# event_id: 1038
# total number of scored particles in event:	 8596
# number of successfully sorted particles:	 8577
# percentage of partices successfully sorted	: 99.77896696137738
#
#
#
# event_id: 1039
# total number of scored particles in event:	 6260
# number of successfully sorted particles:	 6248
# percentage of partices successfully sorted	: 99.80830670926518
#
#
#
# event_id: 1040
# total number of scored particles in event:	 9511
# number of successfully sorted particles:	 9488
# percentage of partices successfully sorted	: 99.75817474503206
#
#
#
# event_id: 1041
# total number of scored particles in event:	 7465
# number of successfully sorted particles:	 7448
# percentage of partices successfully sorted	: 99.7722705961152
#
#
#
# event_id: 1042
# total number of scored particles in event:	 8096
# number of successfully sorted particles:	 8077
# percentage of partices successfully sorted	: 99.7653162055336
#
#
#
# event_id: 1043
# total number of scored particles in event:	 8071
# number of successfully sorted particles:	 8058
# percentage of partices successfully sorted	: 99.83892950068146
#
#
#
# event_id: 1044
# total number of scored particles in event:	 6811
# number of successfully sorted particles:	 6798
# percentage of partices successfully sorted	: 99.80913228600792
#
#
#
# event_id: 1045
# total number of scored particles in event:	 8337
# number of successfully sorted particles:	 8327
# percentage of partices successfully sorted	: 99.88005277677821
#
#
#
# event_id: 1046
# total number of scored particles in event:	 7881
# number of successfully sorted particles:	 7866
# percentage of partices successfully sorted	: 99.80966882375333
#
#
#
# event_id: 1047
# total number of scored particles in event:	 7011
# number of successfully sorted particles:	 6999
# percentage of partices successfully sorted	: 99.8288403936671
#
#
#
# event_id: 1048
# total number of scored particles in event:	 7483
# number of successfully sorted particles:	 7468
# percentage of partices successfully sorted	: 99.7995456367767
#
#
#
# event_id: 1049
# total number of scored particles in event:	 8690
# number of successfully sorted particles:	 8677
# percentage of partices successfully sorted	: 99.85040276179517
#
#
#
# event_id: 1050
# total number of scored particles in event:	 8442
# number of successfully sorted particles:	 8427
# percentage of partices successfully sorted	: 99.82231698649609
#
#
#
# event_id: 1051
# total number of scored particles in event:	 8881
# number of successfully sorted particles:	 8858
# percentage of partices successfully sorted	: 99.7410201553879
#
#
#
# event_id: 1052
# total number of scored particles in event:	 7388
# number of successfully sorted particles:	 7370
# percentage of partices successfully sorted	: 99.75636166756902
#
#
#
# event_id: 1053
# total number of scored particles in event:	 8845
# number of successfully sorted particles:	 8814
# percentage of partices successfully sorted	: 99.64951950254381
#
#
#
# event_id: 1054
# total number of scored particles in event:	 7619
# number of successfully sorted particles:	 7605
# percentage of partices successfully sorted	: 99.81624885155533
#
#
#
# event_id: 1055
# total number of scored particles in event:	 7956
# number of successfully sorted particles:	 7944
# percentage of partices successfully sorted	: 99.84917043740573
#
#
#
# event_id: 1056
# total number of scored particles in event:	 6942
# number of successfully sorted particles:	 6931
# percentage of partices successfully sorted	: 99.8415442235667
#
#
#
# event_id: 1057
# total number of scored particles in event:	 7144
# number of successfully sorted particles:	 7126
# percentage of partices successfully sorted	: 99.74804031354984
#
#
#
# event_id: 1058
# total number of scored particles in event:	 8974
# number of successfully sorted particles:	 8966
# percentage of partices successfully sorted	: 99.91085357700022
#
#
#
# event_id: 1059
# total number of scored particles in event:	 7984
# number of successfully sorted particles:	 7971
# percentage of partices successfully sorted	: 99.83717434869739
#
#
#
# event_id: 1060
# total number of scored particles in event:	 8783
# number of successfully sorted particles:	 8772
# percentage of partices successfully sorted	: 99.87475805533417
#
#
#
# event_id: 1061
# total number of scored particles in event:	 7029
# number of successfully sorted particles:	 7017
# percentage of partices successfully sorted	: 99.82927870251814
#
#
#
# event_id: 1062
# total number of scored particles in event:	 5313
# number of successfully sorted particles:	 5305
# percentage of partices successfully sorted	: 99.84942593638246
#
#
#
# event_id: 1063
# total number of scored particles in event:	 7035
# number of successfully sorted particles:	 7028
# percentage of partices successfully sorted	: 99.90049751243781
#
#
#
# event_id: 1064
# total number of scored particles in event:	 7889
# number of successfully sorted particles:	 7873
# percentage of partices successfully sorted	: 99.79718595512739
#
#
#
# event_id: 1065
# total number of scored particles in event:	 7811
# number of successfully sorted particles:	 7795
# percentage of partices successfully sorted	: 99.7951606708488
#
#
#
# event_id: 1066
# total number of scored particles in event:	 8696
# number of successfully sorted particles:	 8679
# percentage of partices successfully sorted	: 99.80450781968722
#
#
#
# event_id: 1067
# total number of scored particles in event:	 6835
# number of successfully sorted particles:	 6823
# percentage of partices successfully sorted	: 99.82443306510608
#
#
#
# event_id: 1068
# total number of scored particles in event:	 7530
# number of successfully sorted particles:	 7514
# percentage of partices successfully sorted	: 99.7875166002656
#
#
#
# event_id: 1069
# total number of scored particles in event:	 8246
# number of successfully sorted particles:	 8235
# percentage of partices successfully sorted	: 99.86660198884307
#
#
#
# event_id: 1070
# total number of scored particles in event:	 7650
# number of successfully sorted particles:	 7640
# percentage of partices successfully sorted	: 99.86928104575163
#
#
#
# event_id: 1071
# total number of scored particles in event:	 7376
# number of successfully sorted particles:	 7357
# percentage of partices successfully sorted	: 99.74240780911063
#
#
#
# event_id: 1072
# total number of scored particles in event:	 7776
# number of successfully sorted particles:	 7763
# percentage of partices successfully sorted	: 99.83281893004116
#
#
#
# event_id: 1073
# total number of scored particles in event:	 8732
# number of successfully sorted particles:	 8718
# percentage of partices successfully sorted	: 99.83967017865324
#
#
#
# event_id: 1074
# total number of scored particles in event:	 8279
# number of successfully sorted particles:	 8259
# percentage of partices successfully sorted	: 99.75842493054716
#
#
#
# event_id: 1075
# total number of scored particles in event:	 7976
# number of successfully sorted particles:	 7967
# percentage of partices successfully sorted	: 99.88716148445336
#
#
#
# event_id: 1076
# total number of scored particles in event:	 7390
# number of successfully sorted particles:	 7371
# percentage of partices successfully sorted	: 99.74289580514208
#
#
#
# event_id: 1077
# total number of scored particles in event:	 7013
# number of successfully sorted particles:	 6995
# percentage of partices successfully sorted	: 99.7433338086411
#
#
#
# event_id: 1078
# total number of scored particles in event:	 7302
# number of successfully sorted particles:	 7291
# percentage of partices successfully sorted	: 99.84935634072856
#
#
#
# event_id: 1079
# total number of scored particles in event:	 8957
# number of successfully sorted particles:	 8951
# percentage of partices successfully sorted	: 99.93301328569834
#
#
#
# event_id: 1080
# total number of scored particles in event:	 9145
# number of successfully sorted particles:	 9131
# percentage of partices successfully sorted	: 99.84691088026244
#
#
#
# event_id: 1081
# total number of scored particles in event:	 7954
# number of successfully sorted particles:	 7935
# percentage of partices successfully sorted	: 99.76112647724415
#
#
#
# event_id: 1082
# total number of scored particles in event:	 6692
# number of successfully sorted particles:	 6679
# percentage of partices successfully sorted	: 99.80573819485953
#
#
#
# event_id: 1083
# total number of scored particles in event:	 7946
# number of successfully sorted particles:	 7924
# percentage of partices successfully sorted	: 99.72313113516235
#
#
#
# event_id: 1084
# total number of scored particles in event:	 8947
# number of successfully sorted particles:	 8919
# percentage of partices successfully sorted	: 99.68704593718564
#
#
#
# event_id: 1085
# total number of scored particles in event:	 8744
# number of successfully sorted particles:	 8726
# percentage of partices successfully sorted	: 99.79414455626716
#
#
#
# event_id: 1086
# total number of scored particles in event:	 9117
# number of successfully sorted particles:	 9108
# percentage of partices successfully sorted	: 99.90128331688055
#
#
#
# event_id: 1087
# total number of scored particles in event:	 10689
# number of successfully sorted particles:	 10673
# percentage of partices successfully sorted	: 99.85031340630555
#
#
#
# event_id: 1088
# total number of scored particles in event:	 9039
# number of successfully sorted particles:	 9019
# percentage of partices successfully sorted	: 99.77873658590552
#
#
#
# event_id: 1089
# total number of scored particles in event:	 7847
# number of successfully sorted particles:	 7839
# percentage of partices successfully sorted	: 99.89805021027144
#
#
#
# event_id: 1090
# total number of scored particles in event:	 7342
# number of successfully sorted particles:	 7330
# percentage of partices successfully sorted	: 99.83655679651321
#
#
#
# event_id: 1091
# total number of scored particles in event:	 7257
# number of successfully sorted particles:	 7243
# percentage of partices successfully sorted	: 99.80708281659088
#
#
#
# event_id: 1092
# total number of scored particles in event:	 9206
# number of successfully sorted particles:	 9191
# percentage of partices successfully sorted	: 99.83706278514012
#
#
#
# event_id: 1093
# total number of scored particles in event:	 9450
# number of successfully sorted particles:	 9431
# percentage of partices successfully sorted	: 99.7989417989418
#
#
#
# event_id: 1094
# total number of scored particles in event:	 8785
# number of successfully sorted particles:	 8770
# percentage of partices successfully sorted	: 99.82925441092772
#
#
#
# event_id: 1095
# total number of scored particles in event:	 8316
# number of successfully sorted particles:	 8303
# percentage of partices successfully sorted	: 99.84367484367485
#
#
#
# event_id: 1096
# total number of scored particles in event:	 7649
# number of successfully sorted particles:	 7633
# percentage of partices successfully sorted	: 99.7908223297163
#
#
#
# event_id: 1097
# total number of scored particles in event:	 9174
# number of successfully sorted particles:	 9154
# percentage of partices successfully sorted	: 99.78199258774798
#
#
#
# event_id: 1098
# total number of scored particles in event:	 7348
# number of successfully sorted particles:	 7322
# percentage of partices successfully sorted	: 99.64616222101252
#
#
#
# event_id: 1099
# total number of scored particles in event:	 8930
# number of successfully sorted particles:	 8910
# percentage of partices successfully sorted	: 99.77603583426652
#
#
#
# event_id: 1100
# total number of scored particles in event:	 8176
# number of successfully sorted particles:	 8162
# percentage of partices successfully sorted	: 99.82876712328768
#
#
#
# event_id: 1101
# total number of scored particles in event:	 8776
# number of successfully sorted particles:	 8759
# percentage of partices successfully sorted	: 99.80628988149499
#
#
#
# event_id: 1102
# total number of scored particles in event:	 9069
# number of successfully sorted particles:	 9051
# percentage of partices successfully sorted	: 99.801521667218
#
#
#
# event_id: 1103
# total number of scored particles in event:	 7996
# number of successfully sorted particles:	 7986
# percentage of partices successfully sorted	: 99.87493746873437
#
#
#
# event_id: 1104
# total number of scored particles in event:	 8144
# number of successfully sorted particles:	 8130
# percentage of partices successfully sorted	: 99.82809430255402
#
#
#
# event_id: 1105
# total number of scored particles in event:	 6733
# number of successfully sorted particles:	 6718
# percentage of partices successfully sorted	: 99.77721669389574
#
#
#
# event_id: 1106
# total number of scored particles in event:	 7952
# number of successfully sorted particles:	 7936
# percentage of partices successfully sorted	: 99.79879275653923
#
#
#
# event_id: 1107
# total number of scored particles in event:	 8106
# number of successfully sorted particles:	 8090
# percentage of partices successfully sorted	: 99.8026153466568
#
#
#
# event_id: 1108
# total number of scored particles in event:	 9141
# number of successfully sorted particles:	 9124
# percentage of partices successfully sorted	: 99.81402472377202
#
#
#
# event_id: 1109
# total number of scored particles in event:	 9152
# number of successfully sorted particles:	 9139
# percentage of partices successfully sorted	: 99.85795454545455
#
#
#
# event_id: 1110
# total number of scored particles in event:	 7321
# number of successfully sorted particles:	 7310
# percentage of partices successfully sorted	: 99.8497473022811
#
#
#
# event_id: 1111
# total number of scored particles in event:	 7502
# number of successfully sorted particles:	 7486
# percentage of partices successfully sorted	: 99.78672354038923
#
#
#
# event_id: 1112
# total number of scored particles in event:	 8633
# number of successfully sorted particles:	 8615
# percentage of partices successfully sorted	: 99.79149774122553
#
#
#
# event_id: 1113
# total number of scored particles in event:	 8650
# number of successfully sorted particles:	 8635
# percentage of partices successfully sorted	: 99.82658959537572
#
#
#
# event_id: 1114
# total number of scored particles in event:	 9012
# number of successfully sorted particles:	 8990
# percentage of partices successfully sorted	: 99.75588104749224
#
#
#
# event_id: 1115
# total number of scored particles in event:	 8638
# number of successfully sorted particles:	 8623
# percentage of partices successfully sorted	: 99.82634869182681
#
#
#
# event_id: 1116
# total number of scored particles in event:	 7240
# number of successfully sorted particles:	 7226
# percentage of partices successfully sorted	: 99.80662983425414
#
#
#
# event_id: 1117
# total number of scored particles in event:	 10022
# number of successfully sorted particles:	 10004
# percentage of partices successfully sorted	: 99.82039513071243
#
#
#
# event_id: 1118
# total number of scored particles in event:	 8211
# number of successfully sorted particles:	 8197
# percentage of partices successfully sorted	: 99.82949701619778
#
#
#
# event_id: 1119
# total number of scored particles in event:	 7643
# number of successfully sorted particles:	 7623
# percentage of partices successfully sorted	: 99.7383226481748
#
#
#
# event_id: 1120
# total number of scored particles in event:	 6184
# number of successfully sorted particles:	 6173
# percentage of partices successfully sorted	: 99.82212160413971
#
#
#
# event_id: 1121
# total number of scored particles in event:	 8819
# number of successfully sorted particles:	 8803
# percentage of partices successfully sorted	: 99.81857353441433
#
#
#
# event_id: 1122
# total number of scored particles in event:	 8292
# number of successfully sorted particles:	 8272
# percentage of partices successfully sorted	: 99.75880366618428
#
#
#
# event_id: 1123
# total number of scored particles in event:	 6953
# number of successfully sorted particles:	 6945
# percentage of partices successfully sorted	: 99.88494175176183
#
#
#
# event_id: 1124
# total number of scored particles in event:	 9386
# number of successfully sorted particles:	 9364
# percentage of partices successfully sorted	: 99.76560835286597
#
#
#
# event_id: 1125
# total number of scored particles in event:	 8231
# number of successfully sorted particles:	 8211
# percentage of partices successfully sorted	: 99.75701615842546
#
#
#
# event_id: 1126
# total number of scored particles in event:	 7244
# number of successfully sorted particles:	 7231
# percentage of partices successfully sorted	: 99.8205411374931
#
#
#
# event_id: 1127
# total number of scored particles in event:	 6378
# number of successfully sorted particles:	 6367
# percentage of partices successfully sorted	: 99.82753214173722
#
#
#
# event_id: 1128
# total number of scored particles in event:	 7210
# number of successfully sorted particles:	 7196
# percentage of partices successfully sorted	: 99.80582524271844
#
#
#
# event_id: 1129
# total number of scored particles in event:	 7070
# number of successfully sorted particles:	 7058
# percentage of partices successfully sorted	: 99.83026874115983
#
#
#
# event_id: 1130
# total number of scored particles in event:	 8611
# number of successfully sorted particles:	 8595
# percentage of partices successfully sorted	: 99.81419115085356
#
#
#
# event_id: 1131
# total number of scored particles in event:	 6918
# number of successfully sorted particles:	 6902
# percentage of partices successfully sorted	: 99.76871928302978
#
#
#
# event_id: 1132
# total number of scored particles in event:	 8470
# number of successfully sorted particles:	 8458
# percentage of partices successfully sorted	: 99.85832349468713
#
#
#
# event_id: 1133
# total number of scored particles in event:	 8015
# number of successfully sorted particles:	 7998
# percentage of partices successfully sorted	: 99.78789769182782
#
#
#
# event_id: 1134
# total number of scored particles in event:	 9176
# number of successfully sorted particles:	 9166
# percentage of partices successfully sorted	: 99.89102005231038
#
#
#
# event_id: 1135
# total number of scored particles in event:	 7560
# number of successfully sorted particles:	 7543
# percentage of partices successfully sorted	: 99.77513227513228
#
#
#
# event_id: 1136
# total number of scored particles in event:	 8896
# number of successfully sorted particles:	 8881
# percentage of partices successfully sorted	: 99.83138489208633
#
#
#
# event_id: 1137
# total number of scored particles in event:	 8713
# number of successfully sorted particles:	 8691
# percentage of partices successfully sorted	: 99.74750373005854
#
#
#
# event_id: 1138
# total number of scored particles in event:	 8726
# number of successfully sorted particles:	 8706
# percentage of partices successfully sorted	: 99.77079990831996
#
#
#
# event_id: 1139
# total number of scored particles in event:	 9994
# number of successfully sorted particles:	 9978
# percentage of partices successfully sorted	: 99.83990394236542
#
#
#
# event_id: 1140
# total number of scored particles in event:	 8084
# number of successfully sorted particles:	 8061
# percentage of partices successfully sorted	: 99.71548738248391
#
#
#
# event_id: 1141
# total number of scored particles in event:	 9379
# number of successfully sorted particles:	 9368
# percentage of partices successfully sorted	: 99.88271670753812
#
#
#
# event_id: 1142
# total number of scored particles in event:	 7094
# number of successfully sorted particles:	 7073
# percentage of partices successfully sorted	: 99.70397519030166
#
#
#
# event_id: 1143
# total number of scored particles in event:	 8457
# number of successfully sorted particles:	 8435
# percentage of partices successfully sorted	: 99.73986047061605
#
#
#
# event_id: 1144
# total number of scored particles in event:	 8887
# number of successfully sorted particles:	 8873
# percentage of partices successfully sorted	: 99.84246652413638
#
#
#
# event_id: 1145
# total number of scored particles in event:	 7499
# number of successfully sorted particles:	 7482
# percentage of partices successfully sorted	: 99.77330310708095
#
#
#
# event_id: 1146
# total number of scored particles in event:	 7584
# number of successfully sorted particles:	 7567
# percentage of partices successfully sorted	: 99.77584388185655
#
#
#
# event_id: 1147
# total number of scored particles in event:	 8148
# number of successfully sorted particles:	 8128
# percentage of partices successfully sorted	: 99.7545409916544
#
#
#
# event_id: 1148
# total number of scored particles in event:	 6506
# number of successfully sorted particles:	 6499
# percentage of partices successfully sorted	: 99.89240700891484
#
#
#
# event_id: 1149
# total number of scored particles in event:	 9829
# number of successfully sorted particles:	 9814
# percentage of partices successfully sorted	: 99.84739037541968
#
#
#
# event_id: 1150
# total number of scored particles in event:	 9193
# number of successfully sorted particles:	 9172
# percentage of partices successfully sorted	: 99.77156532144022
#
#
#
# event_id: 1151
# total number of scored particles in event:	 6439
# number of successfully sorted particles:	 6430
# percentage of partices successfully sorted	: 99.86022674328312
#
#
#
# event_id: 1152
# total number of scored particles in event:	 9580
# number of successfully sorted particles:	 9559
# percentage of partices successfully sorted	: 99.78079331941545
#
#
#
# event_id: 1153
# total number of scored particles in event:	 8219
# number of successfully sorted particles:	 8211
# percentage of partices successfully sorted	: 99.90266455773208
#
#
#
# event_id: 1154
# total number of scored particles in event:	 8901
# number of successfully sorted particles:	 8882
# percentage of partices successfully sorted	: 99.78654083810808
#
#
#
# event_id: 1155
# total number of scored particles in event:	 7447
# number of successfully sorted particles:	 7430
# percentage of partices successfully sorted	: 99.77172015576743
#
#
#
# event_id: 1156
# total number of scored particles in event:	 8790
# number of successfully sorted particles:	 8772
# percentage of partices successfully sorted	: 99.79522184300342
#
#
#
# event_id: 1157
# total number of scored particles in event:	 10388
# number of successfully sorted particles:	 10370
# percentage of partices successfully sorted	: 99.82672314208702
#
#
#
# event_id: 1158
# total number of scored particles in event:	 8364
# number of successfully sorted particles:	 8346
# percentage of partices successfully sorted	: 99.78479196556671
#
#
#
# event_id: 1159
# total number of scored particles in event:	 8760
# number of successfully sorted particles:	 8742
# percentage of partices successfully sorted	: 99.79452054794521
#
#
#
# event_id: 1160
# total number of scored particles in event:	 6862
# number of successfully sorted particles:	 6847
# percentage of partices successfully sorted	: 99.78140483823958
#
#
#
# event_id: 1161
# total number of scored particles in event:	 9303
# number of successfully sorted particles:	 9283
# percentage of partices successfully sorted	: 99.78501558637
#
#
#
# event_id: 1162
# total number of scored particles in event:	 8676
# number of successfully sorted particles:	 8656
# percentage of partices successfully sorted	: 99.76947902259106
#
#
#
# event_id: 1163
# total number of scored particles in event:	 8087
# number of successfully sorted particles:	 8069
# percentage of partices successfully sorted	: 99.77742055150242
#
#
#
# event_id: 1164
# total number of scored particles in event:	 9526
# number of successfully sorted particles:	 9507
# percentage of partices successfully sorted	: 99.80054587444887
#
#
#
# event_id: 1165
# total number of scored particles in event:	 8496
# number of successfully sorted particles:	 8478
# percentage of partices successfully sorted	: 99.78813559322033
#
#
#
# event_id: 1166
# total number of scored particles in event:	 6602
# number of successfully sorted particles:	 6589
# percentage of partices successfully sorted	: 99.80308997273553
#
#
#
# event_id: 1167
# total number of scored particles in event:	 9113
# number of successfully sorted particles:	 9094
# percentage of partices successfully sorted	: 99.79150663886755
#
#
#
# event_id: 1168
# total number of scored particles in event:	 8257
# number of successfully sorted particles:	 8244
# percentage of partices successfully sorted	: 99.84255782972023
#
#
#
# event_id: 1169
# total number of scored particles in event:	 8464
# number of successfully sorted particles:	 8451
# percentage of partices successfully sorted	: 99.84640831758034
#
#
#
# event_id: 1170
# total number of scored particles in event:	 7369
# number of successfully sorted particles:	 7350
# percentage of partices successfully sorted	: 99.74216311575519
#
#
#
# event_id: 1171
# total number of scored particles in event:	 8271
# number of successfully sorted particles:	 8257
# percentage of partices successfully sorted	: 99.83073388949342
#
#
#
# event_id: 1172
# total number of scored particles in event:	 7665
# number of successfully sorted particles:	 7647
# percentage of partices successfully sorted	: 99.76516634050881
#
#
#
# event_id: 1173
# total number of scored particles in event:	 8393
# number of successfully sorted particles:	 8384
# percentage of partices successfully sorted	: 99.89276778267605
#
#
#
# event_id: 1174
# total number of scored particles in event:	 9781
# number of successfully sorted particles:	 9769
# percentage of partices successfully sorted	: 99.87731315816379
#
#
#
# event_id: 1175
# total number of scored particles in event:	 9043
# number of successfully sorted particles:	 9019
# percentage of partices successfully sorted	: 99.73460134910981
#
#
#
# event_id: 1176
# total number of scored particles in event:	 8276
# number of successfully sorted particles:	 8258
# percentage of partices successfully sorted	: 99.78250362493958
#
#
#
# event_id: 1177
# total number of scored particles in event:	 8954
# number of successfully sorted particles:	 8942
# percentage of partices successfully sorted	: 99.8659816841635
#
#
#
# event_id: 1178
# total number of scored particles in event:	 6367
# number of successfully sorted particles:	 6351
# percentage of partices successfully sorted	: 99.74870425632166
#
#
#
# event_id: 1179
# total number of scored particles in event:	 8241
# number of successfully sorted particles:	 8229
# percentage of partices successfully sorted	: 99.85438660356753
#
#
#
# event_id: 1180
# total number of scored particles in event:	 8826
# number of successfully sorted particles:	 8818
# percentage of partices successfully sorted	: 99.90935871289372
#
#
#
# event_id: 1181
# total number of scored particles in event:	 7247
# number of successfully sorted particles:	 7238
# percentage of partices successfully sorted	: 99.87581068028149
#
#
#
# event_id: 1182
# total number of scored particles in event:	 8949
# number of successfully sorted particles:	 8926
# percentage of partices successfully sorted	: 99.7429880433568
#
#
#
# event_id: 1183
# total number of scored particles in event:	 7364
# number of successfully sorted particles:	 7353
# percentage of partices successfully sorted	: 99.85062466051059
#
#
#
# event_id: 1184
# total number of scored particles in event:	 7215
# number of successfully sorted particles:	 7204
# percentage of partices successfully sorted	: 99.84753984753985
#
#
#
# event_id: 1185
# total number of scored particles in event:	 8159
# number of successfully sorted particles:	 8141
# percentage of partices successfully sorted	: 99.77938472852065
#
#
#
# event_id: 1186
# total number of scored particles in event:	 7596
# number of successfully sorted particles:	 7588
# percentage of partices successfully sorted	: 99.89468141126909
#
#
#
# event_id: 1187
# total number of scored particles in event:	 10539
# number of successfully sorted particles:	 10523
# percentage of partices successfully sorted	: 99.84818293955783
#
#
#
# event_id: 1188
# total number of scored particles in event:	 9291
# number of successfully sorted particles:	 9271
# percentage of partices successfully sorted	: 99.78473791841567
#
#
#
# event_id: 1189
# total number of scored particles in event:	 8257
# number of successfully sorted particles:	 8235
# percentage of partices successfully sorted	: 99.73355940414194
#
#
#
# event_id: 1190
# total number of scored particles in event:	 8343
# number of successfully sorted particles:	 8327
# percentage of partices successfully sorted	: 99.80822246194414
#
#
#
# event_id: 1191
# total number of scored particles in event:	 6586
# number of successfully sorted particles:	 6574
# percentage of partices successfully sorted	: 99.8177953234133
#
#
#
# event_id: 1192
# total number of scored particles in event:	 8465
# number of successfully sorted particles:	 8447
# percentage of partices successfully sorted	: 99.78735971647963
#
#
#
# event_id: 1193
# total number of scored particles in event:	 6339
# number of successfully sorted particles:	 6331
# percentage of partices successfully sorted	: 99.87379712888468
#
#
#
# event_id: 1194
# total number of scored particles in event:	 7903
# number of successfully sorted particles:	 7885
# percentage of partices successfully sorted	: 99.77223839048463
#
#
#
# event_id: 1195
# total number of scored particles in event:	 8351
# number of successfully sorted particles:	 8336
# percentage of partices successfully sorted	: 99.82038079271943
#
#
#
# event_id: 1196
# total number of scored particles in event:	 7079
# number of successfully sorted particles:	 7064
# percentage of partices successfully sorted	: 99.7881056646419
#
#
#
# event_id: 1197
# total number of scored particles in event:	 8083
# number of successfully sorted particles:	 8066
# percentage of partices successfully sorted	: 99.78968204874428
#
#
#
# event_id: 1198
# total number of scored particles in event:	 7120
# number of successfully sorted particles:	 7109
# percentage of partices successfully sorted	: 99.84550561797752
#
#
#
# event_id: 1199
# total number of scored particles in event:	 7543
# number of successfully sorted particles:	 7531
# percentage of partices successfully sorted	: 99.84091210393743
#
#
#
# event_id: 1200
# total number of scored particles in event:	 9031
# number of successfully sorted particles:	 9012
# percentage of partices successfully sorted	: 99.78961355331636
#
#
#
# event_id: 1201
# total number of scored particles in event:	 7230
# number of successfully sorted particles:	 7218
# percentage of partices successfully sorted	: 99.83402489626556
#
#
#
# event_id: 1202
# total number of scored particles in event:	 9946
# number of successfully sorted particles:	 9932
# percentage of partices successfully sorted	: 99.85923989543535
#
#
#
# event_id: 1203
# total number of scored particles in event:	 8676
# number of successfully sorted particles:	 8660
# percentage of partices successfully sorted	: 99.81558321807285
#
#
#
# event_id: 1204
# total number of scored particles in event:	 8484
# number of successfully sorted particles:	 8467
# percentage of partices successfully sorted	: 99.7996228194248
#
#
#
# event_id: 1205
# total number of scored particles in event:	 8988
# number of successfully sorted particles:	 8968
# percentage of partices successfully sorted	: 99.7774810858923
#
#
#
# event_id: 1206
# total number of scored particles in event:	 9526
# number of successfully sorted particles:	 9502
# percentage of partices successfully sorted	: 99.74805794667226
#
#
#
# event_id: 1207
# total number of scored particles in event:	 10665
# number of successfully sorted particles:	 10641
# percentage of partices successfully sorted	: 99.77496483825598
#
#
#
# event_id: 1208
# total number of scored particles in event:	 6848
# number of successfully sorted particles:	 6830
# percentage of partices successfully sorted	: 99.73714953271028
#
#
#
# event_id: 1209
# total number of scored particles in event:	 8257
# number of successfully sorted particles:	 8243
# percentage of partices successfully sorted	: 99.83044689354487
#
#
#
# event_id: 1210
# total number of scored particles in event:	 7406
# number of successfully sorted particles:	 7391
# percentage of partices successfully sorted	: 99.79746151768836
#
#
#
# event_id: 1211
# total number of scored particles in event:	 9441
# number of successfully sorted particles:	 9416
# percentage of partices successfully sorted	: 99.7351975426332
#
#
#
# event_id: 1212
# total number of scored particles in event:	 8829
# number of successfully sorted particles:	 8813
# percentage of partices successfully sorted	: 99.818779023672
#
#
#
# event_id: 1213
# total number of scored particles in event:	 6769
# number of successfully sorted particles:	 6757
# percentage of partices successfully sorted	: 99.82272122913281
#
#
#
# event_id: 1214
# total number of scored particles in event:	 8968
# number of successfully sorted particles:	 8948
# percentage of partices successfully sorted	: 99.77698483496877
#
#
#
# event_id: 1215
# total number of scored particles in event:	 7716
# number of successfully sorted particles:	 7692
# percentage of partices successfully sorted	: 99.68895800933126
#
#
#
# event_id: 1216
# total number of scored particles in event:	 5846
# number of successfully sorted particles:	 5830
# percentage of partices successfully sorted	: 99.72630858706808
#
#
#
# event_id: 1217
# total number of scored particles in event:	 10528
# number of successfully sorted particles:	 10505
# percentage of partices successfully sorted	: 99.78153495440729
#
#
#
# event_id: 1218
# total number of scored particles in event:	 6401
# number of successfully sorted particles:	 6392
# percentage of partices successfully sorted	: 99.85939696922355
#
#
#
# event_id: 1219
# total number of scored particles in event:	 7821
# number of successfully sorted particles:	 7806
# percentage of partices successfully sorted	: 99.80820866896816
#
#
#
# event_id: 1220
# total number of scored particles in event:	 7768
# number of successfully sorted particles:	 7757
# percentage of partices successfully sorted	: 99.85839340885686
#
#
#
# event_id: 1221
# total number of scored particles in event:	 7844
# number of successfully sorted particles:	 7826
# percentage of partices successfully sorted	: 99.77052524222336
#
#
#
# event_id: 1222
# total number of scored particles in event:	 6009
# number of successfully sorted particles:	 6004
# percentage of partices successfully sorted	: 99.9167914794475
#
#
#
# event_id: 1223
# total number of scored particles in event:	 7949
# number of successfully sorted particles:	 7926
# percentage of partices successfully sorted	: 99.71065542835576
#
#
#
# event_id: 1224
# total number of scored particles in event:	 8379
# number of successfully sorted particles:	 8365
# percentage of partices successfully sorted	: 99.83291562238931
#
#
#
# event_id: 1225
# total number of scored particles in event:	 9290
# number of successfully sorted particles:	 9274
# percentage of partices successfully sorted	: 99.82777179763187
#
#
#
# event_id: 1226
# total number of scored particles in event:	 9492
# number of successfully sorted particles:	 9469
# percentage of partices successfully sorted	: 99.75769068689422
#
#
#
# event_id: 1227
# total number of scored particles in event:	 7983
# number of successfully sorted particles:	 7961
# percentage of partices successfully sorted	: 99.72441438055868
#
#
#
# event_id: 1228
# total number of scored particles in event:	 7870
# number of successfully sorted particles:	 7854
# percentage of partices successfully sorted	: 99.79669631512071
#
#
#
# event_id: 1229
# total number of scored particles in event:	 7931
# number of successfully sorted particles:	 7907
# percentage of partices successfully sorted	: 99.69738998865212
#
#
#
# event_id: 1230
# total number of scored particles in event:	 8715
# number of successfully sorted particles:	 8691
# percentage of partices successfully sorted	: 99.72461273666093
#
#
#
# event_id: 1231
# total number of scored particles in event:	 7010
# number of successfully sorted particles:	 7003
# percentage of partices successfully sorted	: 99.90014265335235
#
#
#
# event_id: 1232
# total number of scored particles in event:	 8068
# number of successfully sorted particles:	 8055
# percentage of partices successfully sorted	: 99.8388696083292
#
#
#
# event_id: 1233
# total number of scored particles in event:	 7018
# number of successfully sorted particles:	 7001
# percentage of partices successfully sorted	: 99.75776574522656
#
#
#
# event_id: 1234
# total number of scored particles in event:	 8095
# number of successfully sorted particles:	 8075
# percentage of partices successfully sorted	: 99.75293390982088
#
#
#
# event_id: 1235
# total number of scored particles in event:	 7581
# number of successfully sorted particles:	 7569
# percentage of partices successfully sorted	: 99.8417095370004
#
#
#
# event_id: 1236
# total number of scored particles in event:	 7779
# number of successfully sorted particles:	 7764
# percentage of partices successfully sorted	: 99.80717315850366
#
#
#
# event_id: 1237
# total number of scored particles in event:	 6925
# number of successfully sorted particles:	 6905
# percentage of partices successfully sorted	: 99.71119133574007
#
#
#
# event_id: 1238
# total number of scored particles in event:	 9273
# number of successfully sorted particles:	 9251
# percentage of partices successfully sorted	: 99.76275207591934
#
#
#
# event_id: 1239
# total number of scored particles in event:	 8174
# number of successfully sorted particles:	 8160
# percentage of partices successfully sorted	: 99.82872522632738
#
#
#
# event_id: 1240
# total number of scored particles in event:	 7237
# number of successfully sorted particles:	 7223
# percentage of partices successfully sorted	: 99.80654967527981
#
#
#
# event_id: 1241
# total number of scored particles in event:	 9046
# number of successfully sorted particles:	 9029
# percentage of partices successfully sorted	: 99.81207163387133
#
#
#
# event_id: 1242
# total number of scored particles in event:	 6429
# number of successfully sorted particles:	 6417
# percentage of partices successfully sorted	: 99.8133457769482
#
#
#
# event_id: 1243
# total number of scored particles in event:	 7780
# number of successfully sorted particles:	 7768
# percentage of partices successfully sorted	: 99.84575835475579
#
#
#
# event_id: 1244
# total number of scored particles in event:	 7387
# number of successfully sorted particles:	 7365
# percentage of partices successfully sorted	: 99.702179504535
#
#
#
# event_id: 1245
# total number of scored particles in event:	 7478
# number of successfully sorted particles:	 7466
# percentage of partices successfully sorted	: 99.83952928590533
#
#
#
# event_id: 1246
# total number of scored particles in event:	 8295
# number of successfully sorted particles:	 8281
# percentage of partices successfully sorted	: 99.83122362869199
#
#
#
# event_id: 1247
# total number of scored particles in event:	 7160
# number of successfully sorted particles:	 7149
# percentage of partices successfully sorted	: 99.8463687150838
#
#
#
# event_id: 1248
# total number of scored particles in event:	 7356
# number of successfully sorted particles:	 7341
# percentage of partices successfully sorted	: 99.79608482871126
#
#
#
# event_id: 1249
# total number of scored particles in event:	 8667
# number of successfully sorted particles:	 8644
# percentage of partices successfully sorted	: 99.73462559132341
#
#
#
# event_id: 1250
# total number of scored particles in event:	 7476
# number of successfully sorted particles:	 7462
# percentage of partices successfully sorted	: 99.812734082397
#
#
#
# event_id: 1251
# total number of scored particles in event:	 7351
# number of successfully sorted particles:	 7336
# percentage of partices successfully sorted	: 99.79594612977826
#
#
#
# event_id: 1252
# total number of scored particles in event:	 8273
# number of successfully sorted particles:	 8257
# percentage of partices successfully sorted	: 99.80659978242475
#
#
#
# event_id: 1253
# total number of scored particles in event:	 8272
# number of successfully sorted particles:	 8254
# percentage of partices successfully sorted	: 99.78239845261122
#
#
#
# event_id: 1254
# total number of scored particles in event:	 7007
# number of successfully sorted particles:	 6995
# percentage of partices successfully sorted	: 99.82874268588554
#
#
#
# event_id: 1255
# total number of scored particles in event:	 8861
# number of successfully sorted particles:	 8839
# percentage of partices successfully sorted	: 99.75172102471504
#
#
#
# event_id: 1256
# total number of scored particles in event:	 6976
# number of successfully sorted particles:	 6961
# percentage of partices successfully sorted	: 99.78497706422019
#
#
#
# event_id: 1257
# total number of scored particles in event:	 8733
# number of successfully sorted particles:	 8719
# percentage of partices successfully sorted	: 99.83968853773045
#
#
#
# event_id: 1258
# total number of scored particles in event:	 9101
# number of successfully sorted particles:	 9081
# percentage of partices successfully sorted	: 99.78024392923855
#
#
#
# event_id: 1259
# total number of scored particles in event:	 9230
# number of successfully sorted particles:	 9217
# percentage of partices successfully sorted	: 99.85915492957747
#
#
#
# event_id: 1260
# total number of scored particles in event:	 7669
# number of successfully sorted particles:	 7651
# percentage of partices successfully sorted	: 99.76528882514017
#
#
#
# event_id: 1261
# total number of scored particles in event:	 8651
# number of successfully sorted particles:	 8636
# percentage of partices successfully sorted	: 99.82660964050399
#
#
#
# event_id: 1262
# total number of scored particles in event:	 8544
# number of successfully sorted particles:	 8522
# percentage of partices successfully sorted	: 99.74250936329588
#
#
#
# event_id: 1263
# total number of scored particles in event:	 7624
# number of successfully sorted particles:	 7610
# percentage of partices successfully sorted	: 99.81636935991605
#
#
#
# event_id: 1264
# total number of scored particles in event:	 9021
# number of successfully sorted particles:	 9001
# percentage of partices successfully sorted	: 99.77829508923622
#
#
#
# event_id: 1265
# total number of scored particles in event:	 8621
# number of successfully sorted particles:	 8603
# percentage of partices successfully sorted	: 99.79120751652941
#
#
#
# event_id: 1266
# total number of scored particles in event:	 8981
# number of successfully sorted particles:	 8958
# percentage of partices successfully sorted	: 99.74390379690458
#
#
#
# event_id: 1267
# total number of scored particles in event:	 7523
# number of successfully sorted particles:	 7510
# percentage of partices successfully sorted	: 99.82719659710222
#
#
#
# event_id: 1268
# total number of scored particles in event:	 8420
# number of successfully sorted particles:	 8405
# percentage of partices successfully sorted	: 99.82185273159145
#
#
#
# event_id: 1269
# total number of scored particles in event:	 6631
# number of successfully sorted particles:	 6615
# percentage of partices successfully sorted	: 99.75870909365104
#
#
#
# event_id: 1270
# total number of scored particles in event:	 7731
# number of successfully sorted particles:	 7721
# percentage of partices successfully sorted	: 99.87065062734446
#
#
#
# event_id: 1271
# ...
# percentage of partices successfully sorted	: 99.76910390324355
#
#
#
# event_id: 3500
# total number of scored particles in event:	 7958
# number of successfully sorted particles:	 7948
# percentage of partices successfully sorted	: 99.87434028650415
#
#
#
# event_id: 3501
# total number of scored particles in event:	 8520
# number of successfully sorted particles:	 8498
# percentage of partices successfully sorted	: 99.74178403755869
#
#
#
# event_id: 3502
# total number of scored particles in event:	 7310
# number of successfully sorted particles:	 7296
# percentage of partices successfully sorted	: 99.80848153214774
#
#
#
# event_id: 3503
# total number of scored particles in event:	 9357
# number of successfully sorted particles:	 9334
# percentage of partices successfully sorted	: 99.75419472053008
#
#
#
# event_id: 3504
# total number of scored particles in event:	 8552
# number of successfully sorted particles:	 8535
# percentage of partices successfully sorted	: 99.80121608980356
#
#
#
# event_id: 3505
# total number of scored particles in event:	 8264
# number of successfully sorted particles:	 8241
# percentage of partices successfully sorted	: 99.7216844143272
#
#
#
# event_id: 3506
# total number of scored particles in event:	 7965
# number of successfully sorted particles:	 7941
# percentage of partices successfully sorted	: 99.69868173258004
#
#
#
# event_id: 3507
# total number of scored particles in event:	 8741
# number of successfully sorted particles:	 8726
# percentage of partices successfully sorted	: 99.82839492048964
#
#
#
# event_id: 3508
# total number of scored particles in event:	 7072
# number of successfully sorted particles:	 7055
# percentage of partices successfully sorted	: 99.75961538461539
#
#
#
# event_id: 3509
# total number of scored particles in event:	 8761
# number of successfully sorted particles:	 8745
# percentage of partices successfully sorted	: 99.81737244606781
#
#
#
# event_id: 3510
# total number of scored particles in event:	 8474
# number of successfully sorted particles:	 8451
# percentage of partices successfully sorted	: 99.72858154354496
#
#
#
# event_id: 3511
# total number of scored particles in event:	 8789
# number of successfully sorted particles:	 8775
# percentage of partices successfully sorted	: 99.84070997838207
#
#
#
# event_id: 3512
# total number of scored particles in event:	 7187
# number of successfully sorted particles:	 7176
# percentage of partices successfully sorted	: 99.84694587449562
#
#
#
# event_id: 3513
# total number of scored particles in event:	 8333
# number of successfully sorted particles:	 8317
# percentage of partices successfully sorted	: 99.80799231969279
#
#
#
# event_id: 3514
# total number of scored particles in event:	 8562
# number of successfully sorted particles:	 8547
# percentage of partices successfully sorted	: 99.82480728801681
#
#
#
# event_id: 3515
# total number of scored particles in event:	 9070
# number of successfully sorted particles:	 9051
# percentage of partices successfully sorted	: 99.79051819184123
#
#
#
# event_id: 3516
# total number of scored particles in event:	 8470
# number of successfully sorted particles:	 8454
# percentage of partices successfully sorted	: 99.81109799291617
#
#
#
# event_id: 3517
# total number of scored particles in event:	 8621
# number of successfully sorted particles:	 8605
# percentage of partices successfully sorted	: 99.81440668135947
#
#
#
# event_id: 3518
# total number of scored particles in event:	 8371
# number of successfully sorted particles:	 8346
# percentage of partices successfully sorted	: 99.70134989845897
#
#
#
# event_id: 3519
# total number of scored particles in event:	 9925
# number of successfully sorted particles:	 9906
# percentage of partices successfully sorted	: 99.80856423173803
#
#
#
# event_id: 3520
# total number of scored particles in event:	 8483
# number of successfully sorted particles:	 8472
# percentage of partices successfully sorted	: 99.87032889308028
#
#
#
# event_id: 3521
# total number of scored particles in event:	 7500
# number of successfully sorted particles:	 7485
# percentage of partices successfully sorted	: 99.8
#
#
#
# event_id: 3522
# total number of scored particles in event:	 8578
# number of successfully sorted particles:	 8558
# percentage of partices successfully sorted	: 99.76684541851247
#
#
#
# event_id: 3523
# total number of scored particles in event:	 7164
# number of successfully sorted particles:	 7148
# percentage of partices successfully sorted	: 99.77666108319374
#
#
#
# event_id: 3524
# total number of scored particles in event:	 9777
# number of successfully sorted particles:	 9753
# percentage of partices successfully sorted	: 99.75452592819883
#
#
#
# event_id: 3525
# total number of scored particles in event:	 6864
# number of successfully sorted particles:	 6844
# percentage of partices successfully sorted	: 99.70862470862471
#
#
#
# event_id: 3526
# total number of scored particles in event:	 7794
# number of successfully sorted particles:	 7777
# percentage of partices successfully sorted	: 99.7818835001283
#
#
#
# event_id: 3527
# total number of scored particles in event:	 9509
# number of successfully sorted particles:	 9492
# percentage of partices successfully sorted	: 99.82122200021033
#
#
#
# event_id: 3528
# total number of scored particles in event:	 9828
# number of successfully sorted particles:	 9808
# percentage of partices successfully sorted	: 99.7964997964998
#
#
#
# event_id: 3529
# total number of scored particles in event:	 5768
# number of successfully sorted particles:	 5758
# percentage of partices successfully sorted	: 99.82662968099861
#
#
#
# event_id: 3530
# total number of scored particles in event:	 7837
# number of successfully sorted particles:	 7815
# percentage of partices successfully sorted	: 99.71928033686359
#
#
#
# event_id: 3531
# total number of scored particles in event:	 8121
# number of successfully sorted particles:	 8099
# percentage of partices successfully sorted	: 99.7290974017978
#
#
#
# event_id: 3532
# total number of scored particles in event:	 7951
# number of successfully sorted particles:	 7934
# percentage of partices successfully sorted	: 99.78619041629983
#
#
#
# event_id: 3533
# total number of scored particles in event:	 9448
# number of successfully sorted particles:	 9428
# percentage of partices successfully sorted	: 99.7883149872989
#
#
#
# event_id: 3534
# total number of scored particles in event:	 6753
# number of successfully sorted particles:	 6736
# percentage of partices successfully sorted	: 99.74826003257812
#
#
#
# event_id: 3535
# total number of scored particles in event:	 7925
# number of successfully sorted particles:	 7913
# percentage of partices successfully sorted	: 99.84858044164038
#
#
#
# event_id: 3536
# total number of scored particles in event:	 8330
# number of successfully sorted particles:	 8315
# percentage of partices successfully sorted	: 99.81992797118848
#
#
#
# event_id: 3537
# total number of scored particles in event:	 7886
# number of successfully sorted particles:	 7879
# percentage of partices successfully sorted	: 99.91123510017754
#
#
#
# event_id: 3538
# total number of scored particles in event:	 7371
# number of successfully sorted particles:	 7359
# percentage of partices successfully sorted	: 99.83719983719983
#
#
#
# event_id: 3539
# total number of scored particles in event:	 7109
# number of successfully sorted particles:	 7086
# percentage of partices successfully sorted	: 99.67646645097763
#
#
#
# event_id: 3540
# total number of scored particles in event:	 10238
# number of successfully sorted particles:	 10214
# percentage of partices successfully sorted	: 99.76557921469036
#
#
#
# event_id: 3541
# total number of scored particles in event:	 9131
# number of successfully sorted particles:	 9115
# percentage of partices successfully sorted	: 99.82477275216296
#
#
#
# event_id: 3542
# total number of scored particles in event:	 8854
# number of successfully sorted particles:	 8836
# percentage of partices successfully sorted	: 99.7967020555681
#
#
#
# event_id: 3543
# total number of scored particles in event:	 7846
# number of successfully sorted particles:	 7841
# percentage of partices successfully sorted	: 99.93627326026001
#
#
#
# event_id: 3544
# total number of scored particles in event:	 7658
# number of successfully sorted particles:	 7648
# percentage of partices successfully sorted	: 99.86941760250718
#
#
#
# event_id: 3545
# total number of scored particles in event:	 8350
# number of successfully sorted particles:	 8333
# percentage of partices successfully sorted	: 99.79640718562874
#
#
#
# event_id: 3546
# total number of scored particles in event:	 8587
# number of successfully sorted particles:	 8576
# percentage of partices successfully sorted	: 99.87189938278793
#
#
#
# event_id: 3547
# total number of scored particles in event:	 9269
# number of successfully sorted particles:	 9254
# percentage of partices successfully sorted	: 99.83817024490236
#
#
#
# event_id: 3548
# total number of scored particles in event:	 7625
# number of successfully sorted particles:	 7603
# percentage of partices successfully sorted	: 99.71147540983607
#
#
#
# event_id: 3549
# total number of scored particles in event:	 6800
# number of successfully sorted particles:	 6788
# percentage of partices successfully sorted	: 99.82352941176471
#
#
#
# event_id: 3550
# total number of scored particles in event:	 9234
# number of successfully sorted particles:	 9214
# percentage of partices successfully sorted	: 99.78340914013428
#
#
#
# event_id: 3551
# total number of scored particles in event:	 9370
# number of successfully sorted particles:	 9353
# percentage of partices successfully sorted	: 99.81856990394877
#
#
#
# event_id: 3552
# total number of scored particles in event:	 8518
# number of successfully sorted particles:	 8500
# percentage of partices successfully sorted	: 99.78868278938718
#
#
#
# event_id: 3553
# total number of scored particles in event:	 6318
# number of successfully sorted particles:	 6306
# percentage of partices successfully sorted	: 99.81006647673314
#
#
#
# event_id: 3554
# total number of scored particles in event:	 7637
# number of successfully sorted particles:	 7620
# percentage of partices successfully sorted	: 99.77739950242241
#
#
#
# event_id: 3555
# total number of scored particles in event:	 8801
# number of successfully sorted particles:	 8787
# percentage of partices successfully sorted	: 99.84092716736734
#
#
#
# event_id: 3556
# total number of scored particles in event:	 9639
# number of successfully sorted particles:	 9618
# percentage of partices successfully sorted	: 99.78213507625273
#
#
#
# event_id: 3557
# total number of scored particles in event:	 8967
# number of successfully sorted particles:	 8953
# percentage of partices successfully sorted	: 99.84387197501951
#
#
#
# event_id: 3558
# total number of scored particles in event:	 8980
# number of successfully sorted particles:	 8960
# percentage of partices successfully sorted	: 99.77728285077951
#
#
#
# event_id: 3559
# total number of scored particles in event:	 8062
# number of successfully sorted particles:	 8049
# percentage of partices successfully sorted	: 99.83874968990325
#
#
#
# event_id: 3560
# total number of scored particles in event:	 8792
# number of successfully sorted particles:	 8776
# percentage of partices successfully sorted	: 99.81801637852594
#
#
#
# event_id: 3561
# total number of scored particles in event:	 9069
# number of successfully sorted particles:	 9047
# percentage of partices successfully sorted	: 99.75741537104422
#
#
#
# event_id: 3562
# total number of scored particles in event:	 8361
# number of successfully sorted particles:	 8348
# percentage of partices successfully sorted	: 99.84451620619544
#
#
#
# event_id: 3563
# total number of scored particles in event:	 9188
# number of successfully sorted particles:	 9177
# percentage of partices successfully sorted	: 99.88027862429256
#
#
#
# event_id: 3564
# total number of scored particles in event:	 7314
# number of successfully sorted particles:	 7300
# percentage of partices successfully sorted	: 99.80858627290128
#
#
#
# event_id: 3565
# total number of scored particles in event:	 6555
# number of successfully sorted particles:	 6542
# percentage of partices successfully sorted	: 99.80167810831426
#
#
#
# event_id: 3566
# total number of scored particles in event:	 8650
# number of successfully sorted particles:	 8634
# percentage of partices successfully sorted	: 99.81502890173411
#
#
#
# event_id: 3567
# total number of scored particles in event:	 9183
# number of successfully sorted particles:	 9172
# percentage of partices successfully sorted	: 99.88021343787433
#
#
#
# event_id: 3568
# total number of scored particles in event:	 7166
# number of successfully sorted particles:	 7153
# percentage of partices successfully sorted	: 99.81858777560703
#
#
#
# event_id: 3569
# total number of scored particles in event:	 6967
# number of successfully sorted particles:	 6952
# percentage of partices successfully sorted	: 99.78469929668437
#
#
#
# event_id: 3570
# total number of scored particles in event:	 6517
# number of successfully sorted particles:	 6507
# percentage of partices successfully sorted	: 99.84655516341876
#
#
#
# event_id: 3571
# total number of scored particles in event:	 8428
# number of successfully sorted particles:	 8412
# percentage of partices successfully sorted	: 99.81015662078785
#
#
#
# event_id: 3572
# total number of scored particles in event:	 9021
# number of successfully sorted particles:	 9005
# percentage of partices successfully sorted	: 99.82263607138898
#
#
#
# event_id: 3573
# total number of scored particles in event:	 7844
# number of successfully sorted particles:	 7830
# percentage of partices successfully sorted	: 99.82151963284039
#
#
#
# event_id: 3574
# total number of scored particles in event:	 7976
# number of successfully sorted particles:	 7953
# percentage of partices successfully sorted	: 99.71163490471415
#
#
#
# event_id: 3575
# total number of scored particles in event:	 7721
# number of successfully sorted particles:	 7703
# percentage of partices successfully sorted	: 99.76686957647973
#
#
#
# event_id: 3576
# total number of scored particles in event:	 7166
# number of successfully sorted particles:	 7151
# percentage of partices successfully sorted	: 99.7906782026235
#
#
#
# event_id: 3577
# total number of scored particles in event:	 8488
# number of successfully sorted particles:	 8472
# percentage of partices successfully sorted	: 99.8114985862394
#
#
#
# event_id: 3578
# total number of scored particles in event:	 8422
# number of successfully sorted particles:	 8408
# percentage of partices successfully sorted	: 99.83376870102113
#
#
#
# event_id: 3579
# total number of scored particles in event:	 7757
# number of successfully sorted particles:	 7741
# percentage of partices successfully sorted	: 99.79373469124661
#
#
#
# event_id: 3580
# total number of scored particles in event:	 9775
# number of successfully sorted particles:	 9759
# percentage of partices successfully sorted	: 99.83631713554988
#
#
#
# event_id: 3581
# total number of scored particles in event:	 6444
# number of successfully sorted particles:	 6432
# percentage of partices successfully sorted	: 99.81378026070763
#
#
#
# event_id: 3582
# total number of scored particles in event:	 7620
# number of successfully sorted particles:	 7604
# percentage of partices successfully sorted	: 99.79002624671917
#
#
#
# event_id: 3583
# total number of scored particles in event:	 8506
# number of successfully sorted particles:	 8487
# percentage of partices successfully sorted	: 99.77662826240301
#
#
#
# event_id: 3584
# total number of scored particles in event:	 8255
# number of successfully sorted particles:	 8242
# percentage of partices successfully sorted	: 99.84251968503936
#
#
#
# event_id: 3585
# total number of scored particles in event:	 9002
# number of successfully sorted particles:	 8987
# percentage of partices successfully sorted	: 99.83337036214175
#
#
#
# event_id: 3586
# total number of scored particles in event:	 7860
# number of successfully sorted particles:	 7842
# percentage of partices successfully sorted	: 99.77099236641222
#
#
#
# event_id: 3587
# total number of scored particles in event:	 8482
# number of successfully sorted particles:	 8463
# percentage of partices successfully sorted	: 99.77599622730489
#
#
#
# event_id: 3588
# total number of scored particles in event:	 8848
# number of successfully sorted particles:	 8839
# percentage of partices successfully sorted	: 99.89828209764919
#
#
#
# event_id: 3589
# total number of scored particles in event:	 8316
# number of successfully sorted particles:	 8293
# percentage of partices successfully sorted	: 99.72342472342473
#
#
#
# event_id: 3590
